# %%
# Setup
from bs4 import BeautifulSoup
from collections import OrderedDict
import requests
import pandas as pd

# %%
headers = {'User-Agent': 'Mozilla/5.0',
           'From': 'itchyandscratchy@gmail.com'
          }

# %%
url = 'https://www.ontariouniversitiesinfo.ca/programs/all'
with requests.get(url, headers=headers) as u:     
    soup = BeautifulSoup(u.content) #
    
    print(soup.body.prettify())
# Out:
# <body>
#  <!-- Google Tag Manager -->
#  <script>
#   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WK89JGQ');
#  </script>
#  <!-- End Google Tag Manager -->
#  <div id="_top">
#  </div>
#  <header class="site-header" id="top" role="banner" tabindex="-1">
#   <div class="skip-links">
#    <a class="visuallyhidden focusable" href="#content">
#     Skip to content
#    </a>
#    <a class="visuallyhidden focusable" href="#navigation">
#     Skip to navigation
#    </a>
#   </div>
#   <ul class="actions actions-language">
#    <li class="action">
#     <a href="/fr/programmes/chercher">
#      Français
#     </a>
#    </li>
#   </ul>
#   <div class="fixed-wrap-viewport-md">
# ...

# %%
period_tags = soup.body.select(".pagination a")
periods = [pt.get_text().lower() for pt in period_tags]

# %%
with requests.get(url, headers=headers) as u:     
    soup = BeautifulSoup(u.content) #<----------------- Making the soup
    
    print(soup.body.find_all('h2', {"class": "result-heading"}))
# Out:
# [<h2 class="result-heading"><a href="/programs/22">Accounting</a></h2>, <h2 class="result-heading"><a href="/programs/3099">Accounting</a></h2>, <h2 class="result-heading"><a href="/programs/7410">Accounting </a></h2>, <h2 class="result-heading"><a href="/programs/627">Accounting (4 years) (French Immersion is available)</a></h2>, <h2 class="result-heading"><a href="/programs/301">Accounting and Financial Management (co-op only)</a></h2>, <h2 class="result-heading"><a href="/programs/872">Accounting (BA 3 year)</a></h2>, <h2 class="result-heading"><a href="/programs/5069">Accounting &amp; Finance</a></h2>, <h2 class="result-heading"><a href="/programs/417">Acting</a></h2>, <h2 class="result-heading"><a href="/programs/7396">Acting (3 years)</a></h2>, <h2 class="result-heading"><a href="/programs/7422">Actuarial Science</a></h2>, <h2 class="result-heading"><a href="/programs/7421">Actuarial Science</a></h2>, <h2 class="result-heading"><a href="/programs/2054">Actuarial Science (BA)</a
# ...

# %%
collected_data = []

for i in pages:
    
    url = 'https://www.ontariouniversitiesinfo.ca/programs/search/?search=&group={}'.format(i)

    with requests.get(url, headers=headers) as u:     
        soup = BeautifulSoup(u.content) #<----------------- Making the soup

        # Loop across each fruit list (alphabetical)
        for j in soup.body.find_all('h2', {"class": "result-heading"}):
            for k in j.find_all('a'):    # Loop through each item in fruits that start with A, B, etc..        
                programs = OrderedDict()

                print(k.text)

                # Save data to OrderedDict()
                programs['program'] = k.text
                #programs['next_data_item'] = k.find_next_sibling('a')

                collected_data.append(programs)

programs_df = pd.DataFrame(collected_data)
# Out:
# Accounting
# Accounting
# Accounting
# Accounting (4 years) (French Immersion is available)
# Accounting and Financial Management (co-op only)
# Accounting (BA 3 year)
# Accounting & Finance
# Acting
# Acting (3 years)
# Actuarial Science
# Actuarial Science
# Actuarial Science (BA)
# Actuarial Sciences (4 years)
# Advertising
# Aeronautics Leadership – Flight
# Aerospace Engineering
# African Studies (International Development Studies BA) Specialization
# Ancient Greek and Roman Studies
# Ancient Greek and Roman Studies and Business
# Ancient Studies
# Animal Biology
# Anishinaabemowin (BA 3 year)
# Anishinaabe Studies (BA 3 year)
# Anthropology
# Anthropology (4 years) (French Immersion is available)
# Anthropology – Legal Studies Option
# Anthropology and Sociology (Joint Honours 4 years) (French Immersion is available)
# Anthropology (BA)
# Anthropology (BA)
# Anthropology (BA, iBA)
# Anthropology (BSc)
# Anthropology (BSc)
# Anthropology & Business Administration
# ...

# %%
programs_df.to_csv('/Users/amanda/Documents/Projects/insight/data/processed/ontario-uni-programs.csv', index=False)
